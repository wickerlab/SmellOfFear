# %% [markdown]
# # Subtitle Sentiment Analysis
#
# Using CoreNLP and a StanfordNLP server to perform sentiment analysis

# %%
from nltk import tokenize
import pandas as pd
import numpy as np
import pickle
import copy
from pycorenlp import StanfordCoreNLP
import logging
import json
from datetime import time

from os import listdir, environ
import pickle

from subtitle_parsing import denoiseSubtitleSpecificProcessing,subtitlePreprocess
import string

from google.cloud import translate_v2 as translate

# %%
environ["GOOGLE_APPLICATION_CREDENTIALS"]="Smell Of Fear-f8e3e23fa7d3.json"

# %% [markdown]
# ### Helper Functions

# %%
#rawSub - subtitles, runtime is the effective runtime 
def divideSubsIntoSegments(lines, runtime):
    
    refEndSec = 30
    refEndMin = 0
    refEndHour = 0
    referenceEndTime = time(refEndHour, refEndMin, refEndSec)
    refStartSec = 0
    refStartMin = 0
    refStartHour = 0
    referenceStartTime = time(refStartHour, refStartMin, refStartSec)
    startTime = None
    
    subtitleIntervals = list()
    
    for segment in range(0, runtime):
        #parse of timing information
        subtitleSegment = list()
        for rowIndex in range(0,len(lines)):
            line = str(lines[rowIndex])
            if len(line) > 15:
                arrow = line[13] + line[14] + line[15]
                if arrow == '-->':
                    #timing information detected
                    #parse the actual time
                    startTime = line[0:8] #extract the start time
                    startHour = int(startTime[0] + startTime[1])
                    startMinutes = int(startTime[3] + startTime[4])
                    startSeconds = int(startTime[6] + startTime[7])
                    startTime = time(startHour,startMinutes,startSeconds)
                    
                    if startTime > referenceEndTime:
                        
                        subtitleIntervals.append(subtitleSegment)
                        
                        refStartSec = refStartSec + 30
                        if refStartSec == 60:
                            refStartSec = 0
                            refStartMin = refStartMin + 1
                        if refStartMin == 60:
                            refStartMin = 0
                            refStartHour = refStartHour + 1
                        
                        refEndSec = refEndSec + 30
                        if refEndSec == 60:
                            refEndMin = refEndMin + 1
                            refEndSec = 0
                        if refEndMin == 60:
                            refEndHour = refEndHour + 1
                            refEndMin = 0
                            
                        referenceEndTime = time(refEndHour, refEndMin, refEndSec)
                        referenceStartTime = time(refStartHour, refStartMin, refStartSec)
                        
                        break
                        
                    continue
                    
            if startTime != None:
                if startTime >= referenceStartTime and startTime <= referenceEndTime:
                    subtitleSegment.append(line)   

    return subtitleIntervals

# %%
#subtitle translation
def translation_processing(translatedSubs):
    
    #remove all unecessary characters from the translated text
    #loop through each segement and each dialog from within each segment
    engTranslated = list()
    for i in range(0, len(translatedSubs)):
        dialog=translatedSubs[i]
        #parse the dialog for weird html characters
        k = 0
        while True:
            try:
                if dialog[k] == '&':
                    index = dialog.index(';')
                    #split off special ascii character
                    asciiChr = dialog[k:index+1]
                    if asciiChr == '&#39;':
                        dialog = dialog[:k] + '\'' + dialog[index+1:]
                    elif asciiChr == '&quot;':
                        dialog = dialog[:k] + '\"' + dialog[index+1:]
                k = k + 1
            except:
                break

        engTranslated.append(dialog)

    return engTranslated

# %% [markdown]
# ### Parsing

# %%
#import srt files
movieRuntimePath = 'data/mounted/Numerical Data/movieRuntimes.csv'
movieRuntimeDf = pd.read_csv(movieRuntimePath, usecols = ['movie', 'effective runtime'])
movieList = list(movieRuntimeDf['movie'])

try:
    rawSubtitles = dict()
    for movie in movieList:
        subPath = 'data/mounted/Features/Subtitles SRT/' + movie + '.srt'
        subs = open(subPath, mode = 'r', encoding='utf-8-sig')
        rawSubtitles[movie] = subs
except FileNotFoundError:
    pass

# %%
#preprocess subtitles
movieSubtitles = dict()
for movie in movieList:
    
    #read in subtitles
    lines = rawSubtitles[movie].readlines() #contains each line within the document
    movieIndex = movieList.index(movie)
    #divide into 30 seconds segment
    segmentList = divideSubsIntoSegments(lines, movieRuntimeDf['effective runtime'][movieIndex])
    
    #denoise and normalise the subtitles
    parsedSegments = denoiseSubtitleSpecificProcessing(segmentList)
    
    #translate subtitles if required to
    if movie == 'Buddy' or movie == 'Suck Me Shakespeer' or movie == 'Help, I Shrunk My Teacher':
        #movie has german subtitles and thus must be translated segment by segment 
        translate_client = translate.Client()
        translatedSegments = list() 
        for segment in parsedSegments:
            # Translates some text from german to english
            translation = translate_client.translate(segment, target_language='en')
            translatedSegments.append(translation['translatedText'])
        
        #process the translation and remove any weird chars
        parsedSegments = translation_processing(translatedSegments)
 
    #process subtitles
    processedSegments = subtitlePreprocess(parsedSegments)
    
    
    passages = list()
    #convert lemmized segments to sentences again
    for segment in processedSegments:
        sentence = str()
        for word in segment:
            sentence +=  " " + word
        
        passages.append(sentence.strip()) 
    
    movieSubtitles[movie] = passages

# %%
for movie in movieList:
    print(movie)
    print(movieSubtitles[movie])
    print('\n')
# Out:
# Hobbit 2
# ['', '', '', 'die thirst come come thank kindly', 'oh watch sorry darling thank master stadle', 'mind join introduce name gandalf gandalf grey', 'gandalf grey know well fine chance bring thorin oakenshield bree receive word father see wander wilds near dunland go look find sign thorin long time since anything rumor hear', 'thrain still live sure father come see go miss say urge march upon erebor rally seven armies dwarves destroy dragon take back lonely mountain would say take back homeland', 'chance meet gandalf lonely mountain trouble thorin dragon sit long enough sooner later darker mind turn towards erebor run unsavory character whilst travel greenway mistake vagabond', 'imagine regret one carry message black speech promise payment head someone want dead thorin wait longer heir throne durin unite armies dwarves', 'together might power retake erebor summon meet seven dwarf families demand stand oath seven armies swear oath one wield king jewel arkenstone thing unite case forget jewel steal smaug help reclaim', 'arkenstone lie half world away bury beneath feet firebreathing dragon yes go need burglar', '', 'close pack close couple league worst wargs pick scent yet another problem see saw tell quiet mouse excellent burglar material', 'listen listen try tell something else form take like bear ye yes bigger much bigger know beast say double back run pack orcs house far might take refuge', 'whose house friend foe neither help us kill us choice none come', 'way quickly run bombur come house run', 'come get inside open door quickly push push', 'dwalin come lads host name beorn skinchanger sometimes huge black bear sometimes great strong man', 'sometimes great strong man bear unpredictable man reason however overfond dwarves leave come away natural none obvious dark spell fool enchantment right get sleep', 'safe tonight hope', '', '', '', '', '', '', '', '', 'one call oakenshield tell azog defiler hunt know azog', 'know azog people first live mountains orcs come north defiler kill family enslave work understand sport cage skinchangers torture seem amuse others like', 'others like many one need reach mountain last days autumn durin day fall yes run time must go mirkwood darkness lie upon forest fell things creep beneath tree', 'alliance orcs moria necromancer dol guldur would venture except great need take elven road path still safe safe wood elves mirkwood like kin less wise dangerous matter mean land crawl orcs', 'land crawl orcs number grow foot never reach forest alive like dwarves greedy blind blind live deem lesser', 'orcs hate need go light hunters far behind', 'elven gate lie path mirkwood sign orcs luck side', 'set ponies loose let return master forest feel sick disease lie upon way around unless go two hundred miles north twice distance south', 'something move shadow unseen hide sight', 'hide sight every day grow strength beware necromancer seem enemy return must know go tombs mountains high fell', 'horse need leave us would unless change bilbo baggins hobbit one leave shire', 'go tell find something goblin tunnel find find courage good well good', 'need wait overlook slop erebor keep map key safe enter mountain without greenwood old air forest heavy illusion seek enter mind lead astray', 'lead us astray mean must stay path leave never find matter may come stay path come must reach mountain sun set durin day durin day let us go one chance find hide door', 'path turn way', 'way air need air head swim happen keep move nori stop path disappear go lose path', 'lose path find look look path remember bite none familiar get hour know even know day end accurse forest', 'attercop', 'look tobacco pouch dwarves woods dwarves blue mountains less exactly mine understand go around circle lose', 'lose keep head east way east lose sun think expert sun find sun need get canopy enough quiet', 'watch', 'see lake river lonely mountain almost', 'almost hear know way go hello hello', 'oh oh come', '', '', 'kill kill eat blood run hide tough goo ...
#
#
# Suck Me Shakespeer
# ['gutgelaunte musik herzlichen gluckwunsch herr popolski und herrates sie haben ihren hauptschulabschluss bestanden herr muller ihre prufung wareine farce ich horte sie werden diese woche entlassen', 'alles gute obwohl sie mit wenig allgemeinbildung eine gefahr fur die offentlichkeit sind wieso haben sie uberhaupt unterricht teilgenommen weil es der einzige ort knast ist wo es umsonst kakao gibt danke schon zwei wochen komm ich nach lass die seife nicht fall', 'fick ne nutte fur mich mit und du tu die pfoten runter gutgelaunte soulpopmusik cheat von john newman', 'soulpopmusik lauft weiter reifen quietschen huhu baby freiheit alter hast du mit meinem auto gemacht geil oder krieg ich mal ein kusschen zur begruung', 'keine ahnung kostet mich das komm heb dir das gelutsche fur deine kundschaft auf wo istdie kohle hab ich vergraben wo denn hiersind die koordinaten bei der stecknadel ich dachte auf nem schulhof guckt kein arsch ist los schlechte erinnerungen die schulzeit du warst auf ner schule wie lange denn', 'bis zur achten oder neunten wei nicht mehr war meine crackphase du zeki krieg ich von dem geld neue titten fresse druck auf die hupe wenn wer kommt und eine die linke die ist irgendwie kleiner ernsthaft jetzt kann ich das radio anmachen nein', 'oh schuhpins charlie hier du ich muss schnell machen ubernimmstdu heute meinen 54dance fuck sag mal die mich verarschen ich steh da nicht drauf tagelang der glitter derarschritze dramatische klange hor aufzu hupen du dachschaden ich bin', 'hor aufzu hupen du dachschaden ich bin hm die stand da neulich noch nicht da war nur ne baustelle ach wirklich du vergrabst es auf ner baustelle ich dachte die verlegen da blo rohre bist du jetzt sauer nein wieso denn auch ich hab ja nur thirteen monate auf diesen scheimoment gewartet vielleicht kann man dieja noch anheben mit nem kran du schuldest mir two thousand euro und fifty fur den glastisch', 'du schuldest mir two thousand euro und fifty fur den glastisch komm runter attila ein zwei wochen hab ich das geld von meinem bruch kleiner vorgeschmack wenn langer dauert alles klar wei bescheid kann ich lange bei dir pennen bis gina von der schlankheitsfarm kommt dann brauch ich das fenster alles okay zieh dich um sexy lehrerin ist dran aufgeht und vergiss die brille nicht laute partymusik', 'musik stoppt abrupt hallo braucht hierjemand nachhilfe ich grabe mich durch den heizungskeller das sind sieben meter istdas nicht ziemlich bescheuert ich glaube schulen sind die kritisch gegenuber kriminellen die kellertunnel graben wollen ich bewerb mich als hausmeister kennst du dich mit instandhaltung aus', 'ich bewerb mich als hausmeister kennst du dich mit instandhaltung aus du bistdie dummste lehrerin derwelt aber auch die geilste burak bruder geht gut und bei dir madchen mann danger gutgelaunte popmusik die fahrraderdarf man nicht umfahren', 'quatsch nicht viel druck dir lieber deine mondkrater aus hallo kann ich ihnen helfen ich das direktorat wegen der stelle ja genau rechts und dann immer geradeaus konnen sie mir kurz helfen mit der brille au tschuldigung war nicht schlimm okay ich mach nen schuh tschuss viel gluck', 'okay ich mach nen schuh tschuss viel gluck nur kurz frau gerster die 10h jetzt nicht frau leimbachknorr die mistviecher haben ich habe vorstellungsgesprache mir steht bis hier naja', 'konnen sie denn gluhbirnen austauschen haben sie den job mal gemacht sind sie elitehausmeisterin und reden nicht mitjedem ey gib mir meine zwei euro ich brauch guthaben burak verpiss dich fick deine mutter fick deine mutter durchsage amokaarm bitte begeben sie sich einen raum standig lauft hiereineramok ey ich hab einen schuss gehort beeilt euch mal', 'das ist ein amokaarm bitte begeben sie sich einen raum und verschlieen sie die tur caro schliet du dann ab ist denn jetzt der pinner hat den alarm ausgelost ich schwore er war verwarnung deine eltern bekommen einen anruf frau gerster ja frau gerster das machtja einen wunderbaren eindruck sind doch nurkinder g ...
#
#
# Walking with Dinosaurs
# ['', '', 'instrumental music play', 'man radio linger cloud around kodiak island look chance overnight shower along mountainous areas south eastern alaska back music kbwz alaska listen', 'ricky brad wait cut cou ntry music play radio dude parent go europe send us alaska hang uncle fine yeah uncle paleontologist collect dinosaur bone guess take us work brad brad brad great signal go anyway give clue', 'get somewhere ah go check friend tooth gorgosaurus cool know almost big trex way faster roam earth millions years ago get wipe live descendants bird blah blah blah oh come man use love dinosaurs expert guy must really scary', 'think lose tooth', 'gorgo yeah wonder like huge fight load dinosaurs friend natalie run flagpole school lose two teeth blood everywhere yeah flagpole let us go sure want come really dig dead things right well stay close truck change mind follow trail', 'get okay bud bird ch irping male voice psst bird caw male voice psst psst hey kid yeah talk', 'yeah talk wrong never hear bird talk think pretty smart right offend things say ancestors totally cool see ancestors three word yougly ch uckles know every fossil tell story tooth tell pretty good one go ahead pick come come pick pick pick', 'come bite anymore least ch uckles however open window ancient past vibrant world wonder danger dinosaurs roam earth bird look little like see begin ch uckles try keep alex seventy million years ago late cretaceous period planet earth', 'live miraculous bird alex boy alexornis mean alexander bird insectivore alex note beautiful plumage majestic wingspan classically curve beak brag kind whole package course familiar cretaceous period probably know hmm', 'watch closely delicate operation best leave professionals ah entice smell decay look tartar buildup mmm hey watch growl tell hard bird enough story see concern friend mine get say pretty good one fill mystery adventure', 'hope despair excuse take personal moment gotcha way guy talk mother pachyrhinosaurus girl pachyrhinosaurus mean thicknosed lizard herbivore alex pay attention adventure son patchi stuff legend nothing stuff right', 'let hey fair alex patchi mmmm barf alex runt litter guy bottom peck order alex hey patchi talk alex try work survival instincts excuse alpha male come pardon go bite back patchi fair share fair share delicious big brother scowler usually really cool get weird around puke mm sometimes get think outside nest', 'sometimes get think outside nest get get nest boy troodon mean wound tooth omnivore alex might say runt get start somewhere zero hero baby whoa whoa whoa hold one tell story credibility story alex yeah neutral perspective wait minute really go eat', 'wait minute really go eat know mom cook still warm uhoh run away go right alex seriously big monster behind sure big monster behind ch uckles screech ing scream alex much survival instincts help roar patch okay quickly learn everybody eat pukedup leave', 'things call meateaters alex exactly friend make almost entirely meat hey put chew toy roar patch good thing dad show alex bulldust patchi 6000pound papa patch nobody mess hey dad little help oh whoa whoa thank groan groan medic', 'patch classic dad man word alex actually man one word roar lou dly one huh alex friend hole head worry one day hole fill greatness patch right plus hardly see alex especially look besides mistake natural young age look leave nest totally worth', 'hey go flatu lence exclaim alex price leave nest oh pretty cool come go hey afraid go eat anything gasp sn iffing hey name patchi want friends', 'wait wait wait always smell like cover poop moment aw come play tag okay guess right growl whoa girl ankylosaur mean fuse lizard herbivore thing huge mean probably steer clear butt alex good patchi learn', 'sn eezes wow beautiful place ever see alex future oil field get attach', 'hey pick someone size uh know mean convenient option oop go lose boy hesperonychus mean western claw carnivore mean oh misunderstand mean brother', 'yeah bigg ...
#
#
# Machete Kills
# ['', '', 'new world enslave land need hero call machete machete machete know score need leader need revolution need machete get space babes people need us machete', 'people need us machete new network galactic shit think god heaven heaven must fall kill bad guy star danny trejo michelle rodriguez eat photons bitch alexa vega justin bieber bleep', 'lady gaga whoever want special guest star leonardo dicaprio man silver mask actor subject change machete kill space', 'rat x cigarette use prolong sexual content pervasive language space violence', '', 'fuck hand assholes ice arrest stay immigration fuck fuck look like get ass grind sweetheart would lose whatever strapdick ride', 'call sweetheart move blow brain jurisdiction goddamned military sell military weapons cartel really think go pay lucky get first cartel', 'el cohete goddamn time fuckholes suppose wait', 'save two know machete enemy cartels lucky day man kill legend become legend', 'man kill legend become legend guy', 'right let us go say cohete guy pros come couple use m16s let us go worth one teach law justice always thing get stop', 'oh shit', 'wish see', 'right remain silent anything say use court law quite resume get taco mean one might consider bite overachiever come kill people bet consider mean motor scooter', 'especially get twenty-four cartel boys lay piece desert well get news taco reserve peons redheaded mongoloid runts los cuerpos los cuerpos take kindly strangers discipline get amen clebourne amen sir see bad news taco one play vigilante around part', 'one play vigilante around part since kill federal officer mine hogkilling good time kill tomato tomato let us get hang detail shall drop clebourne', 'well goddamned say die sir shoot stab', 'shoot stab ever die bullfuckingshit pedro get thick neck sheriff damn sure governor president president yeah', 'president yeah course mr president yes sir', 'machete', '', '', 'machete', 'machete welcome white house good thing get southern hospitality bitch right point like bullshit bite nobullshit guy bullshit aside get someone else need machete', 'get situation hand revolutionary south border name marcos mendez hear crazy mind get missile aim washington say go blow us invade mexico clean cartels stop violence spread across land get basic violation sovereignty aside take bait however know mexico hell mexico', 'want head back south find mendez check say true kill interest motherfucker ask interest president unite fuck state man machete smoke', 'could easily send back pal hang high arizona way see get much chew hombre know criminal record us poof go past longer exist exchange service make legal sign anything', 'sign anything raise right hand none shit stamp bad motherfucker official citizen usa save noose save mine country new country dead girlfriend would want agent sartana', 'machete contact san antonio brief get across border wall nation owe debt gratitude machete go kick ass', 'ladies gentlemen el rey network miss texas pageant present miss san antonio thank believe believe n word equality believe woman right choose choose snow cone mood believe good barbecue twostep right carry gun world peace sure really want talk world peace start tear wall separate us mexico', 'start tear wall separate us mexico wall enable us ignore violence injustice occur thus make world peace nothing beauty pageant pipe dream god bless texas thank', 'must machete blanca vasquez codename miss san antonio handler duration assignment get stitch ear try distract cleavage hairspray', 'part cover gig keep close border designer duds bad either happen world peace fuck world peace m4 carbine longrange get reflex sight micropolymer grip customize trigger fast enough nip jackrabbit roller skate course happen come across jackrabbit roller skate personal favorite grappler', 'fire thirty yards good get scratch hard reach place like like style lowtech mama cane cutter consider swiss army knife machetes machete tell mendez marcos mendez sick twist fuckityfox ever ...
#
#
# Buddy
# ['', 'das ist ja schlimmer als ich dachte ich wei nicht mehr ich tun soll ich hab sogar schon versucht mich umzubringen sie wollten sich das leben nehmen ja mehrfach welchem psychischen zustand befanden sie sich als sie ihn zum ersten mal sahen hatten sie ein traumatisierendes erlebnis waren sie uberarbeitet oder gestresst', 'kam es zur uberreaktion zu wutausbruchen oder zur panikattacke du hast versprochen du haltst die klappe hat er gesagt nein nicht wichtig horen sie ich drehe bald durch mit diesem synapsenstalker seit tagen dusche ich nicht ich rieche es ich brauche medikamente herr weber das hilft nur kurzfristig fangen wir doch lieber noch mal ganz von vorne iiiimonadi von die fantastischen vier', 'iiiimonadi von die fantastischen vier', '', '', 'ach eva wissen sie eigentlich wie spat es ist halb elf eddie wir hatten um zehn eine verabredung schon halb elf sagt man dazu sandy ich bin eddie weit du wo ich bin hier mann hab ich einen schadel ich bin mandy die schwester von sandy tja es sind zwillinge es stehen wichtige entscheidungen konnten sie runterkommen', 'ja klar silvergy der u60energydrink erfrischend belebend der jungbrunnen aus der dose das ist unser hero geschmacksrichtungen sind rote beete palmequitte spargelpassionsfrucht und ingwermohre warum nicht karotte das klingt deutsch verstehe ja ist ganz gut thomas der wahrnehmung der senioren erscheint unser produkt extrem sexy', 'ist doch prima wieso sexy ja wieso glaubwurdig muss es sein das glaubt keiner ich schon das corporate design fordert nostalgie sehnsucht nach verlorener freiheit nach kondition und potenz ein quatsch nicht schlecht nicht schlecht die vertriebswege es gibt immer mehr u60onlineuser diese silver surfer mussen wir auf den einschlagigen seiten einfangen apotheken kurorte friedhofe', 'energydrinks auf friedhofen kann man nicht machen warum nicht ja warum nicht silvergy power bis zum schluss bravo paul das ist gut richtig gut richtig gut warum sind stierhorner auf der dose na ja das ist die mannliche variante wir denken auch schon uber eine dose fur frauen nach soll da drauf sein euter euter', 'das sind ja detail fur sie vielleicht wir sollten es direkt der zielgruppe testen wir konnten seniorenheime damit beliefern das bringt uns garantiert viel aufmerksamkeit sagen sie dazu eddie eddie ja klar wo soll ich unterschreiben wir wussten gerne sie als geschaftsfuhrer von unserem neuen produkt halten', 'hey leute ist das euer ernst ihr seid die profis wenn ihr es sagt dann ist das zeug gut die markteinfuhrung wird teuer aber die konkurrenz entwickelt ein ahnliches produkt den unterlagen alles klar darf ich den behalten die zahlen sind wirklich alarmierend sie sehen alles schwarz und sie eva sehen bunt aus danke war wichtiges unser marktanteil ist keller', 'eine babsi rief sie sucht ihre silikoneinlagen sonst noch mache ich nur ohne sie party wir brauchen zeitgemaere produkte und ein besseres image wieso besseres image ihr lebensstil geht mich nichts aber er farbt auf das unternehmen ab diese farbe steht uns nicht das neue produkt muss ein erfolg werden ich brauche ihre unterstutzung kein problem soll ich tun', 'eddie eddie silvergy wird okologisch produziert ist iaktoseund glutenfrei und sexy ist auch gut fur die nieren fall sie noch eine haben hallo schwester lisa frau schippe machen sie denn hier sie gehoren doch ins bett horst du soren du warst zu fett fur dich mach ich alles', 'willst du nen schluck ist hier los unser neuer getrankelieferant liefert uns energydrinks ich hab zwei kisten abgestaubt damit konnen wir zwei durchbrennen bring lieber die hier zuruck die lagen geschirrspuler schau mir auf die plomben kleines eddie zu mir habt ihr nicht jungeres zeit fur ein foto nein danke na los sie werden vielleicht beruhmt genau ist sie nicht putzig eddie ich hab hier oh das ist lieb wunderbar danke', 'brille ab ach ja hey hey brille sie nicht ist doch nur show wir sind nicht bei den muppets ich mache ihnen einen abzug den abzug mache ich lieber selbst a ...
#
#
# The Hunger Games-Catching Fire
# ['', '', 'easy saw turkeys way cross right front like even rude happen spend six days week work mine', 'happen spend six days week work mine stupid bird start think woods tour leave couple hours well let us go', '', 'hey hey okay let go okay safe okay okay okay', 'sorry go', 'come train station think enough people say goodbye without actually care might easier weeks back snow melt lot happen weeks go gale act yeah good one survive would dead', 'least', 'haymitch haymitch haymitch wake tour day', 'haymitch cameras go hour want baby ask peeta ask ask wake without give pneumonia', 'strangely dislikeable person virtues would like bread katniss eat hob thank welcome two lot warm show time hour take bath haymitch', 'good walk dear walk visitors miss everdeen way please bravery', 'spirit contempt president snow honor dear think make much simpler agree lie think yes think would save time sit please', 'problem miss everdeen problem begin moment reveal poison berry arena head gamemaker seneca crane brain would blow bits expect guess yes think fiasco nothing leave let play little scenario', 'good whole lovecrazed besotted schoolgirl routine impressive truly convince people capitol unfortunately everyone district fell mean know several people view little trick berry act defiance act love girl district twelve place defy capitol walk away unharmed', 'prevent prevent say uprise lead revolution fraction time whole system collapse must fragile system bring berry yes indeed way imagine imagine imagine thousands upon thousands people dead town reduce ash imagine go', 'imagine go make radioactive bury dirt never exist like district thirteen fight hard game miss everdeen game would like real war good neither would mother make peeta lovely boy', 'tell point realize depth indifference towards indifferent lie promise kill want kill want us friends friends ally need', 'need peeta tour need smile need grateful need madly preparedtoenditall love think manage yes yes convince convince miss everdeen', 'convince sake love ones stop take sacred grind', 'history make get use smell hello greatest triumph little superstar sweetie miss cute little house quaint course hear cinna happen cinna oh dear fashion star muse', 'everyone capitol wear everyone everyone well everyone cinna katniss katniss sister oh sweetie okay adorable yeah ready work yeah right good welcome last year 74th hunger game bring us greatest love story time', 'last year 74th hunger game bring us greatest love story time two brave young people odds choose die rather lose nation share agony little time revel joy time do lovely must fee monster right let us go district twelve find starcrossed lovers excite love', 'excite love big smile camera three two one katniss everdeen girl fire peeta mellark baker boy trouble paradise', 'hope right anyone home come back later sorry caesar please right day day go good get good taciturn sudden peeta give detail', 'yeah things great twelve thank generosity capitol never closer twentyfive yards exact fantastic check throughout victory tour thank much katniss everdeen peeta mellark wonderful everybody motion ten nice act', 'almost think kiss real come along children schedule train await fabulous food fabulous wine massage spa treatments tell nothing best two victors need fabulous exactly schedule bite bear twelve days twelve district mostly party celebrations adore fan greet every stop along way', 'wrap capitol need give speeches wave crowd enjoy time spotlight earn say katniss say enjoy katniss earn kill people young lady', 'really mood lecture apologize effie later think haymitch apologize anybody include know fair hold things say game', 'know fair hold things say game save us know go act cameras ignore real life stop look like wound quit act like maybe shoot friends never good friends starters help know person', 'hardly know anything except stubborn good bow sum want tell like say see katniss way whole friend thing work tell deep stuff deep stuff yeah like like ...
#
#
# Walter Mitty
# ['', '', '', '', '', '', 'hi todd maher eharmony', 'help today hi seem leave wink someone know page break maybe break page never hear okay try use eharmony account first time okay look profile pretty intricate match algorithm distinguish us online date service yeah like actually try leave wink one person cheryl melhoff start division work month ago', 'start division work month ago overhear near bagels say site okay unique let ask leave lot stuff like like do section leave blank yeah think skip okay well get help man skip stuff okay well really anywhere noteworthy mentionable do anything noteworthy mentionable', 'hello still hang second god go go go get get go blow go go chip chip thank know build', 'hear bark think smell gas hope okay engineer prosthesis chip sprint stairwell little hipjoint assembly dropring lock anterior pelvic band god noteworthy live abcs adventurous brave creative everything want man man hey man still hey pass like zone second', 'like zone second okay lot normal amount guess yeah get run sorry ookay need lot', 'hey bad day late get acquire yeah weekend walter happy birthday forty-two years old', 'forty-two years old odessa mom make favorite clementine cake suppose retirement place get piano move yes like halfway do piano van street everything fine get phone call really big audition go finish late walter think see need need need rizzo grease understand audition rizzo rizzo rizzo', 'rizzo rizzo tough tender favor please make sure mom piano get move way right go rizzo thank walter happy birthday guess get acquire yeah hear yeah go change downsize us kind dotcom thing possibly wonder thing go transition go play could probably tell ted hendricks manage director transition hey tim naughton sales', 'hey tim naughton sales gary mannheim graphic design cake man um cake today cake man ii deal dirctly dirctly directly life photo units sorry really get song stop listen', 'say know look good beard dumbledore guy guy negative asset manager worth wait', 'ted donny feel tough feel good well get make tough call ahead yeah yeah yeah house picture hey hi', 'hi weekend awesome weekend weekend um let us see bath arctic mountain water latin lover recite verse', 'slut know actually wait refrigerator repairman never come sorry go call later okay ice yes move like woman walter mitty cheryl melhoff test limit human spirit would like climb hair', 'test perhaps contact possibly poetry falcon poetry falcon like think hit paper clip would move yeah know hello actually throw toner box yeah move ii miss great story grind control major tom', 'hear major tom wow move say yeah conference room station people sort thing layouts', 'morning hernando new nut pouch hear yeah meet go evaluate able intricate detail back yeah tricky bewilder evaluate evaluate think let us say hey long neg roll', 'open sean oconnell come morning present send present desk sean oconnell still shoot film result man crush hey want mount seriously sure', 'hear rumble life do man want say thank take look inside gift years hard work sorry neg roll spill blood selfstitching gun wind abdomen number twenty-five best ever quintessence life think trust get need go always', 'get um wallet', 'life motto go twenty-five hey need negative twenty-five sean oconnell send telegram', 'actual telegram 100yearold dude come little hat floor meet bring twenty-five itit somewhere find okay make contact sheet frame soon say anything anyone yeah want inform reluctantly', 'guess start back begin okay want inform reluctantly month issue last yeah bull yeah sad news sure value employees undergo transition life online want candid', 'want candid determine nonvital employees new new partnership decide position remain us course next week also feel sad see good news excite right ted hendricks manage director transition never fun stage ahead us privilege publish', 'privilege publish last issue life magazine final issue receive telegram come sean oconnell never tell will speak executives well break long ...
#
#
# Paranormal Activity
# ['time end time new beginnings time transformation change', 'time new beginnings time transformation change know change always easy change go allow us grow individuals embrace destiny become persons mean become hey jesse one personal favorites william arthur ward bless curse dawn dusk time us embrace next chapter live know ready thank class two thousand and twelve thank thank', 'thank five buck brother fell asleep brother fall asleep bet babas exactly yes principal drink jesse jesse congratulations brother wear shut show love hey look number one right get picture two get picture hector show diploma two three', 'two three take one real quick best friends players oh oh ah look good fool hey oscar good yeah congratulations great speech man mom brother arturo hola guy nice summer right take care brother man camera nice si much three hundred think could like know record stuff', 'mess around drop like camera dad serious right careful hey chavo hear daddy graduate yeah barely hate appreciate hmm seriously though mom would really proud see graduate wish would oh thank like nicest thing ever say oh get use actually get turnout right people actually care hey marisol hey today tell could get work make salsa', 'hey thank congratulations thank much feel feel like man hey give camera dude see chug yeah grandma', 'newspaper window weirdass ana yeah crazy neighbor ana live live right dad room vent connect room sometimes middle night talk like weird sound dude hear like wail moan jess jesse listen get go man come nice right right let us go yeah nice', 'high definition much uh twofifty twofifty two hundred two hundred go somewhere else think two hundred and fifty cheap knock two hundred onefifty know wait minute wait minute come go give one hundred and fifty give two hundred', 'give two hundred give free welcome neighborhood mansion right actually cochinero fuck little man hola right top leave best friend hector live right straight back fuck zoom man shit good', 'crazy ana apartment live right cover windows nobody see go take pad right oh shit sexy man sexy oh fuck hair crazy right pad right anybody hey chavo hey boy look papa', 'yeah think room right oh get check call ghetto barn side room right side dad live cool right get get pawn shop pawn shop look job see bye right love come chavo hey let us go look grandma', 'hey let us go look grandma oh hear probably prayers fuck este es el chake weight mmmkay chake weight oh shake weight shake weight shake weight feel like shake dick something nada ten', 'nada es chake weight okay chavo hear one shake weight get look dumbass fuck oh shake shake oh man would let guy work yeah yeah go finally get shit dawg', 'look right yeah dope drop shit go drop sick man get fire bet work better dumb ass anyways dude look zoom man zoom hella deep come check oh shit fuck oh fuck oh shit oh shit fuck guy nothing man nothing nothing nothing mean nothing get fuck camera even record man swear bullshit even huh fuck hey come give fuck camera fuck go fuck idiot man go run run run', 'yo gopro get camera fuck go dope watch right look way move oh hell get shit eat food eat fuck tortilla right chip anything get shit get go man shut man get ass', 'man shut man get ass fuck go even get insurance go pay stop pussy three two one go shit ah fuck shit ah fell nut oh god dick man god dude like believe actually go man get ass go stupid one high dude holy shit cool man always make dumb shit', 'hey go like feel fuck yo come ana apartment yeah dude ana holy shit dude oscar yo oscar hi jesse man yo fuck dude school yeah man arturo brother dude yeah hell fuck ana apartment', 'fuck ana apartment yo lady fuck weird dude know know ana cook cook irm want tequila get surprise talk oh half get good night sleep whoa fuck look look', 'grandma irma yeah ah whoa oh yeah one round come please', 'wait guy hear', 'someone get fuck oh fuck fuck fuck know sound good though wish could see get little gopro thingy tie put yo', 'yo get yeah dude find little ro ...
#
#
# Star Wars-The Force Awakens
# ['', '', '', '', '', 'begin make things right travel far see much', 'ignore despair galaxy without jedi balance force well chance general long time oh general royalty well certainly get company', 'hide leave go', 'come bb8 hurry', 'stormtrooper blast xwing see', 'take safer get far away hear come back itwill right', '', 'keep move stay', 'look old become something far worse happen', 'know come know come call kylo ren map skywalker know find go give first order first order rise dark side show dark side may try deny truth family right', 'right', 'talk first talk first talk first old man give hard understand search apparatus nothing sir put board phasma sir villagers', 'kill command fire please', 'nothing go ahead', 'right right', 'phasma fn2187 submit blaster inspection yes captain give permission remove helmet sorry captain', 'sorry captain report division', '', '', '', '', 'bring today worth hmm one quarter portion', '', '', '', 'shh teedo want part', 'teedo want part respect anyone antenna bend come classify really big secret niima outpost way stay kelvin ridge', 'keep away sink field north drown sand follow town way', 'morning go welcome idea best pilot resistance board comfortable', 'comfortable really impress one able get map might want rethink technique', 'poe grunt resistance intimidate droid bb unit well jakku soon', 'leave give hope still might show whoever wait classify know wait family back one day come five piece worth let see hmm', 'let see hmm one half portion last week half portion droid pay sixty portion', 'actually droid sale come follow girl get droid ren want prisoner', 'fn2187 turn listen carefully exactly say get rescue help escape fly tie fighter resistance break fly tie fighter fly anything help right thing need pilot', 'need pilot need pilot go yeah okay stay calm stay calm calm talk yet okay go way always want fly one things', 'shoot blasters okay principle use toggle leave switch missiles cannon mag pulse use sight right aim trigger fire complicate fix unsanctioned departure bay two alert general hux stop fighter', 'fourteen fail eighteen get thing really move', 'get take many cannon go get far right go get us position stay sharp ahead ahead see get us dead center clean shoot okay get yeah yes see see saw', 'hey name fn2187 f name ever give well use fn huh finn go call finn right finn yeah finn like like poe poe dameron good meet poe good meet finn sir take turbolasers use ventral cannon yes sir bring online', 'yes sir bring online kylo ren general hux resistance pilot yes help one check register identify stormtrooper one village fn2187 sir ventral cannon hot fire one come toward right leave', 'one come toward right leave see hold see nice shoot go go back jakku go back jakku need get system get get droid first order droid right bb unit orange white one kind care color droid important one pal get get far away first order', 'get get far away first order go back jakku die droid map lead straight luke skywalker oh get kid fn2187 report division evaluate send recondition prior sign nonconformity first offense general hit destroy disable head back jakku fighter project crash goazon badlands go back droid', 'send squad wreckage poe poei poei', 'poei poe get poei poei', '', '', 'supreme leader snoke explicit capture droid destroy must kylo ren capable soldier general question methods obviously skilled commit high treason perhaps leader snoke consider use clone army men exceptionally train program birth problem retrieve droid unharmed', 'careful ren personal interest interfere order leader snoke want map sake suggest get water water water water ls water', 'oi get', 'hey work unkar guy want must really want', 'reyi hurry thief thief ow hey jacket', 'droid say steal pretty mess day right would appreciate stop accuse ow stop get belong master belong poe dameron name right capture first order help escape ship crash poe make', 'try help sorry resistance obviously yes resistance yeah resistance never meet resistance ...
#
#
# I'm Off Then
# ['', '', 'say friends set hike spain bite', 'instead could home lie favorite red sofa drink hot chocolate eat piece lovely cheesecake imagine husband give twenty red roses today spread legs fortnight vase thank thank much thank', 'awesome hp awesome brilliant look great hang great performance hp look like shit thank okay forget meet greet hafeles schwabisch hall want saw really', 'one way hardly stand straight fit fiddle hp hp listen inner voice shout take break months end take toll', 'symptoms similar heart attack lucky remove gall bladder need live without lose weight take sooner acute hear loss recently hoot suffer circulatory problems sweat attack shortness breath definitely', 'biliary colics warn much stress kill suppose nothing nothing three months funny kid herr kerkeling would hate fill death certificate next time big fan', 'herr kerkeling even yesterday spend whole even nothing', 'nothing beatrix expert nothing hp talk please call back misha talk eight answer machine spill hello herr kerkeling fm sure quite busy want ask beatrix movie get crack', 'get crack start get worry please call search god nowadays age everything comfort ovvn sofa long journey still worthwhile time god make mistake god make mistake never unfortunately unfortunately', 'mean simply accept everything happen make one accident could undo god right hans peter god move mysterious ways trust sure god plan hans peter', 'way st jam call therapist help ddrte need shrink need vacation eight hundred km hike mountains bunch', 'lunatics want autograph call vacation seven hundred and ninety-one seven hundred and ninety-one km foot alone need two three months maldives beach stress show fan want exercise yoga shirley maclaine go yes indeed lunatics go hp people go search god', 'yes exactly arrive end sin forgive sound great believe god believe god question ask pancake sandwich boy blood sausage', 'eat anything boy worry grandma morn mom fine lord hans peter dear lord things think long', 'things think long believe god idea believe one thing go like finish know stage know nothing life anything bite hike never harm anyone worst thing happen get slim gazelle', 'would better keep touch send search party really think many germans many germans everywhere', 'know really pas du tout june 9th saintjeanpieddeport look skimp would save wrong place believe', 'really right place one thousands lunatics far least feel like like clerical comedy', '', 'bring caddy camino trail airraid shelter need stuff believe hope one recognize', 'look buy camino gnome good afternoon bonjour hp kerkeling start sure smartypants think saw george clooney last year follow hours look like garmischpartenkirchen', 'go talk excuse hey votre profession artist votre profession profession listen think someone special cut line like votre profession artist writer well know spirit artist body german taxman excuse artist certainly', 'thank journalist bristol today know spirit poet service english tabloid write tabloid ladies gentlemen pilgrims end trail sljacquesdecompostelle receive gild certificate latin la compostella', 'la compostella sin forgive free sin go home monsieur bed number fourteen merci monsieur mademoiselle bed number five window hey chief', 'hat sleep youth hostels ever since school days clairvoyant travel guide say every pilgrim cry least way hi please first day many people look answer every year', 'personally look right question important thing walk whole way believe twenty thirty kilometers every day couch potato set trek god help', 'showoff god yahweh', 'shiva ganesha zeus buddha allah krishna jehovah whatever name may god really exist', 'buen cammo ben cammo look artist yes go ahead catch eventually would mind l thank', 'one hundred waterproof oh thank smoke high life wonderful view sight know must always right dorte souvenir shop saintjean', 'souvenir shop saintjean oh see one cane stella one thousand, nine hundred and eighty-eight stockholm hans peter recklinghausen start buen camino gi ...
#
#
# Help, I Shrunk My Teacher
# ['', '', '', 'ja schnell war hier noch keiner das wird eine super zwischenzeit oh das war knapp aber er hat geschafft jetzt eine wunderschone kurve dann reit er die maschine noch mal um die eigene achse meine damen und herren etwas hab ich ja uberhaupt noch nicht gesehen ja felix und wenn erjetzt keinen fehler mehr macht dann wird das ein neuer weltrekord aber soll denn jetzt bitte noch passieren felix', 'huch wir haben verschlafen heute ist erster schultag otto ganz genau komm beeilung tshirt bringe ich dir noch komm ok hier hat mama dir zum schulstart geschickt cool ziemlich cool hier arm durch jacke', 'fruhstuck ist wichtig los geht du musst dich voll und ganz auf den unterricht konzentrieren ok vorsicht papa hoppala halt dich die regeln ja ja ampel sag mal haben die denn keinen anrufbeantworter der schule felix du bist gerade von der schule geflogen weil du wahrend der mathearbeit gezockt hast wenn du wirklich pilot werden willst mach das ding aus und starte durch felix das ist meine letzte chance hier', 'felix das ist meine letzte chance hier sonst mussen wir umziehen ich hab gelesen der pilotentest ist voll hart vielleicht werde ich doch anderes du willst doch seit jahren ich strenge mich ok', 'komm', 'hallo hier cha oh war ein echter kinderfreund gewesen na ja komm', 'da da machen sie da ach guten tag vorndran mein name das ist mein sohn der felix der geht ab heute hier zur schule und wir wollten uns', 'bei der direktorin melden wir sind leider etwas spat dran da sind sie hier falsch das alte lehrerzimmer wird seit jahren nicht mehr benutzt ach tatsachlich warum nicht sie mussen dort entlang und dann link ja gut dann vielen dank na das ist aber ein komischer vogel', '', 'ja wir sind jetzt ein wenig zu spat entschuldigung es ist nur wir haben einen ganz alten wecker und der', 'lass dich fuhren lautet unser schulmotto das haben sie sicher eingangstor gelesen auf latein', 'wir unterrichten hier seit uber one hundred jahren nach modernsten padagogischen methoden felix vorndran bist du bereit dich diesen unterzuordnen ja also ich wollte hier zur schule gehen wenn ich ehrlich bin habe ich meine zweifel daran ob du hier richtig bist sie auch aber wir haben prinzipien und dank unseres schulgrunders otto leonard', 'und dank unseres schulgrunders otto leonard ist es hier brauch dass jeder ungeachtet seiner herkunft und bisherigen schulleistung gelegenheit erhalt sich zu beweisen also sogar du geil drei monaten wird uber deine aufnahme entschieden der nachsten woche werden zwei klausuren geschrieben die mussen bestanden werden verstehen wir uns fragen ja es wirkt hier ruhig und leer haben sie heute schulausflug hier herrscht disziplin', 'kein toben laufen schreien klettern pfeifen hupfen also nur atmen und lernen leises atmen und lernen bringen sie ihn die 5b danke vielen dank ist doch gar nicht schlecht oder dr schmittgossenwein ich wunschte ich konnte sagen wie schon sie zu sehen herr schulrat henning ich habe ihnen bereits telefon mitgeteilt dass ich heute nicht zu sprechen bin', 'telefon mitgeteilt dass ich heute nicht zu sprechen bin sie konnen die zukunft nicht andern frau schmittgossenwein regeln sind diesem hause regeln sie gelten einmal eingefuhrt fur sie ganz genauso wie fur mich jetzt ist schulersprechstunde danach habe ich unterricht morgen um ten uhr bin ich wieder hier und dann haben sie zeit das bekommen sie noch schriftlich als dienstanweisung das verspreche ich ihnen einer dienstanweisung werde ich selbstverstandlich folge leisten geht mir dieser lade hier auf die nuss', 'du hast nun wirklich gar keinen grund zu lachen rein mit dir solltest du irgendwie arger mit ihr haben dann steil sie dir nackt vor das mache ich immer mit kunden wenn ich arger mit denen hab einfach nackt papa das ist voll krank oder clownskostum oder klein winzigklein das funktioniert auch', 'ich geh rein durchstarten alles roger captain viel spa und benimm dich ja verzieh dich mario', 'hi ich bin felix hi felix wow eine parrot drone mit kamera ...

# %% [markdown]
# # Run NLP Server
#
# Navigate to the directory that contains StanfordNLP then run the following code on Terminal:
#
# ## Run the server in English
# java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -annotators "sentiment" -port 9000 -timeout 30000
#
# ## Run the server in German for Buddy, Suck me Shakespeer and Help, I Shrunk
# java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -annotators "sentiment" -port 9000 -timeout 30000
#
# ### Note
# May need to change the port number if the port is in use

# %%
#For movies with english subtitle scripts
subtitleSentiment = dict()

nlp = StanfordCoreNLP('http://localhost:9000')

for movie in movieList:
    if movie != 'Buddy' and movie != 'Suck Me Shakespeer' and movie != 'Help, I Shrunk My Teacher':
        try:
            subtitleList  = movieSubtitles[movie]
            sentimentMovie = list()
            for segment in subtitleList:
                sentimentSegment = dict()
                sentimentSegmentList = list()
                for line in segment:
                    res = nlp.annotate(line, properties={'annotators': 'sentiment','outputFormat': 'json','timeout': 30000,})
                    sentimentSegment['sentiment'] = res['sentences'][0]['sentiment']
                    sentimentSegment['sentimentValue'] = res['sentences'][0]['sentimentValue']
                    sentimentSegmentList.append(sentimentSegment)
                sentimentMovie.append(sentimentSegmentList)
            subtitleSentiment[movie] = sentimentMovie
        except KeyError:
            pass

# %%
pickle.dump(subtitleSentiment, open('subtitleSentiment.p', 'wb'))

# %%
subtitleSentiment['Hobbit 2']

# %%
subtitleSentiment['Buddy']
