# %%
"""
Purpose:
Author: Hasnain Cheena
Date: 2/1/2019
"""
# Out:
# '\nPurpose:\nAuthor: Hasnain Cheena\nDate: 2/1/2019\n'

# %%
from nltk import tokenize
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle
import pysrt
import indicoio as ind

# %matplotlib inline

# %%
#purpose of function: 
def return_dialog(sub):
    """
    Returns the dialog of the .srt file sub.
    Input :
        sub : name of the .srt file as a string, ex. 's01e01.srt'
    Output :
        dialog : dialog contained in .srt file as a single string
    """
    lines = []
    with open(sub) as file:
        start = 2 
        for index,line in enumerate(file):
            if index >= start:
                # check if line contains dialog
                if (index == start) or ((index == start+1) and (len(line.split()) != 0)):
                    lines.append(line.strip('\n').replace('\'',''))
                    space_index = index
                if ((index > space_index + 2) and (len(line.split()) != 0)):
                    lines.append(line.strip('\n').replace('\'',''))
                if (len(line.split()) == 0):
                    space_index = index
    # output the dialog as a single string, removing the last two lines which contain attribution
    return ' '.join(lines[:-2])

# %%
hobbit2_input_path = r'C:\Users\hasna\Desktop\Smell of Fear\Subtitles_SRT\Hobbit2.srt'
di = return_dialog(hobbit2_input_path)
hobbit_sub = pysrt.open(hobbit2_input_path,encoding='iso-8859-1')

# %%
#split the paragraph into a list of sentences use NLTK 
sentences = tokenize.sent_tokenize(di)

#import movie runtimes
movie_runtime_path = r'C:\Users\hasna\Desktop\Smell of Fear\NumericalData\movie_runtimes.csv'
movie_runtime_df = pd.read_csv(movie_runtime_path, usecols = ['movie', 'runtime', 'runtime (mins)', 'effective runtime'], header = 0, nrows = 6)
movies_30s_list = list() #entire list of movies with each movie in its 30s split config

#split movie subs into 30s increments  
hobbit_30s_incr = list() #list to store a particular movie in its 30s split config 

counter = 0
start_sec = 0
start_min = 0
end_min = 0
end_sec = 30

while(counter < movie_runtime_df.loc[0]['effective runtime']): 
    part = hobbit_sub.slice(starts_after = {'minutes': start_min, 'seconds': start_sec}, ends_before = {'minutes': end_min, 'seconds': end_sec})
    dialogue = str(part.text) #convert subrip to str making it easier to edit 

    hobbit_30s_incr.append(dialogue)
    counter += 1

    start_sec += 30
    end_sec += 30
    if(start_sec >= 60):
        start_sec = 0
        start_min += 1
    if(end_sec >= 60):
        end_sec = 0
        end_min += 1

# %%
#indicoio api key 
ind.config.api_key = 'aa542289fe0643a1335333e7c9bec937'

# %%
#analyse the entire document (HQ Sentiment Analysis)
sentiment = ind.sentiment_hq(di, language ='english')
print(sentiment)
# Out:
# 0.2203713

# %%
#analyse each sentence (HQ Sentiment Analysis)
sentiment = ind.sentiment_hq(sentences)
for i in range(0,len(sentences)):
    print(sentences[i])
    print(sentiment[i])
    print()
# Out:
# Im dying of thirst over here.
# 0.56435394
#
# Come on!
# 0.30658638
#
# Come on!
# 0.30658638
#
# Here you are.
# 0.6239461
#
# Thank you kindly.
# 0.9229347
#
# Oh, watch it!
# 0.9249568
#
# Sorry, darling.
# 0.53742754
#
# There you are.
# 0.48094267
#
# Thank you.
# 0.9005196
#
# Master Stadle.
# 0.94909734
#
# Mind if I join you?
# 0.424775
#
# Ill have the same.
# 0.36303398
#
# I should introduce myself.
# 0.57963127
#
# My name is Gandalf.
# 0.75610304
#
# Gandalf the Grey.
# 0.6161751
#
# I know who you are.
# 0.39944977
#
# Well, now.
# 0.7869477
#
# This is a fine chance.
# 0.8455578
#
# What brings Thorin Oakenshield to Bree?
# 0.69389945
#
# I received word that my father... had been seen wandering the Wilds near Dunland.
# 0.5325512
#
# I went looking.
# 0.3806731
#
# I found no sign of him.
# 0.10585081
#
# Thorin, its been a long time... since anything but rumor was heard... of Thrain.
# 0.686327
#
# He still lives.
# 0.9460763
#
# I am sure of it.
# 0.5968594
#
# ...

# %%
#analyse each 30 second increments (HQ Sentiment Analysis)
hobbit_intervals = list()
for j in hobbit_30s_incr:
    if len(j) == 0:
        pass
    else:
        hobbit_intervals.append(j)
 
sentiment = ind.sentiment_hq(hobbit_intervals)
for i in range(0,len(hobbit_intervals)):
    print(hobbit_intervals[i])
    print(sentiment[i])
    print()
# Out:
# I'm dying of thirst over here.
# Come on! Come on!
# Here you are.
# Thank you kindly.
# 0.561422
#
# Oh, watch it!
# Sorry, darling.
# There you are.
# Thank you.
# Master Stadle.
# 0.85199773
#
# Mind if I join you?
# I'll have the same.
# I should introduce myself.
# My name is Gandalf.
# 0.5057651
#
# Gandalf the Grey.
# I know who you are.
# Well, now. This is a fine chance.
# What brings Thorin
# Oakenshield to Bree?
# I received word that my father...
# had been seen wandering
# the Wilds near Dunland.
# I went looking.
# I found no sign of him.
# Thorin, it's been a long time...
# 0.62952465
#
# of Thrain.
# He still lives.
# I am sure of it.
# My father came to see you
# before he went missing.
# What did you say to him?
# I urged him to march
# upon Erebor, to rally...
# the seven armies of the Dwarves...
# to destroy the dragon
# and take back...
# the Lonely Mountain.
# And I would say the same to you.
# 0.8128006
#
# This is no chance meeting,
# is it, Gandalf?
# No.
# ...
