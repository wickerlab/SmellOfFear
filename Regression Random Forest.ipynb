# %%
import pandas as pd
import numpy as np

import pickle

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
#Import data and objects

#import vocs
co2Df = pickle.load(open("Pickle Objects/normalisedVOC.p", "rb" ))

#import movie runtimes
movieRuntimesPath = 'Numerical Data/movie_runtimes.csv'
movieRuntimeDf = pd.read_csv(movieRuntimesPath, usecols = ['movie', 'runtime (mins)', 'effective runtime'])
movieList = list(movieRuntimeDf['movie'])


#import colour and shade
frameColour = pickle.load(open("Pickle Objects/Colour-Shade Pickle Objects/dominantColourOfMovies.p", "rb" ))
frameShade = pickle.load(open("Pickle Objects/Colour-Shade Pickle Objects/shadeOfMovies.p", "rb" ))

#import audio
audioFeatures = dict()
for movie in movieList:
    audioPath = "Pickle Objects/Audio Feature Pickle Objects/" + movie + ".p"
    try:
        movieAudioFeatures = pickle.load(open(audioPath, "rb" ))
    except FileNotFoundError:
        print(movie)
    audioFeatures[movie] = movieAudioFeatures


#import subtitle 
subtitleSentiment = pickle.load(open("Pickle Objects/subtitleSentiment.p", "rb" ))
# Out:
# I'm Off Then
# Help, I've Shrunk My Teacher

# %%
#group the colour or shade components to within their respective intervals
def grouping(visualList):
    movieVisuals = list()
    for index in range(0, int(len(visualList)/10)):
        try:
            segment = visualList[index*10:index*10+10]
            movieVisuals.append(segment)
        except IndexError:
            pass
        
    return movieVisuals

# %%
#preprocess colour and shade 
#10 frames per 30 second period
#note the shade and colour contain the credit scenes of the movie
movieColour = dict()
movieShade = dict()
for movie in movieList:
    colourMovie = grouping(frameColour[movie])
    shadeMovie = grouping(frameShade[movie])
    movieIndex = movieList.index(movie)
    runtime = movieRuntimeDf.loc[movieIndex]['effective runtime']
    colourMovie = colourMovie[:runtime]
    shadeMovie = shadeMovie[:runtime]
    movieColour[movie] = colourMovie
    movieShade[movie] = shadeMovie

# %%
#preprocess audio 
#note the audio contain the credit scenes
for movieIndex in range(0, len(movieList)):
    movie = movieList[movieIndex]
    movieAudioFeature = audioFeatures[movie]
    audioKeys = list(movieAudioFeature.keys())
    runtime = movieRuntimeDf.loc[movieIndex]['effective runtime']
    for featureIndex in range(0, len(audioKeys)):
        featureName = audioKeys[featureIndex]
        movieAudioFeature[featureName] = movieAudioFeature[featureName][:runtime]

# %%
#audio, subtitle, colour and shade are the features of the movie
#assemble df for all movies apart from Im Off Then and Help I shrunk the teacher
def assembleMovieFeatureDf(audio, subtitle, colour, shade):
# Out:
#   File "<ipython-input-26-5c2b1e9362d9>", line 4
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
#COLOUR 

#slice the colour lists to size
buddy_colour_features = buddy_colour_features[0:buddy_emotion_df.shape[0]]
machete_colour_features = machete_colour_features[0:machete_emotion_df.shape[0]]
walter_colour_features = walter_colour_features[0:walter_emotion_df.shape[0]]
paranormalactivity_colour_features = paranormalactivity_colour_features[0:paranormalactivity_emotion_df.shape[0]]
hungergames_colour_features = hungergames_colour_features[0:hungergames_emotion_df.shape[0]]

#create r g b coloumns 
red_list = list()
blue_list = list()
green_list = list()
for i in range(0,len(buddy_colour_features)):
    red,green,blue = buddy_colour_features[i]
    red_list.append(red)
    green_list.append(green)
    blue_list.append(blue)
buddy_input_df['R'] = red_list
buddy_input_df['G'] = green_list
buddy_input_df['B'] = blue_list

red_list = list()
blue_list = list()
green_list = list()
for i in range(0,len(machete_colour_features)):
    red,green,blue = machete_colour_features[i]
    red_list.append(red)
    green_list.append(green)
    blue_list.append(blue)
machete_input_df['R'] = red_list
machete_input_df['G'] = green_list
machete_input_df['B'] = blue_list

red_list = list()
blue_list = list()
green_list = list()
for i in range(0,len(walter_colour_features)):
    red,green,blue = walter_colour_features[i]
    red_list.append(red)
    green_list.append(green)
    blue_list.append(blue)
walter_input_df['R'] = red_list
walter_input_df['G'] = green_list
walter_input_df['B'] = blue_list

red_list = list()
blue_list = list()
green_list = list()
for i in range(0,len(paranormalactivity_colour_features)):
    red,green,blue = paranormalactivity_colour_features[i]
    red_list.append(red)
    green_list.append(green)
    blue_list.append(blue)
paranormalActivity_input_df['R'] = red_list
paranormalActivity_input_df['G'] = green_list
paranormalActivity_input_df['B'] = blue_list

red_list = list()
blue_list = list()
green_list = list()
for i in range(0,len(hungergames_colour_features)):
    red,green,blue = hungergames_colour_features[i]
    red_list.append(red)
    green_list.append(green)
    blue_list.append(blue)
hungergames_input_df['R'] = red_list
hungergames_input_df['G'] = green_list
hungergames_input_df['B'] = blue_list

# %%
#SUBTITLE 
buddy_input_df['Sentiment'] = buddy_subtitle_features
machete_input_df['Sentiment'] = machete_subtitle_features
walter_input_df['Sentiment'] = walter_subtitle_features
paranormalActivity_input_df['Sentiment'] = paranormal_subtitle_features
hungergames_input_df['Sentiment'] = hungergames_subtitle_features

# %%
print(buddy_input_df)
print(buddy_input_df.shape)
print(machete_input_df.shape)
print(walter_input_df.shape)
print(paranormalActivity_input_df.shape)
print(hungergames_input_df.shape)
# Out:
#      log mel 0  log mel 1  log mel 2  log mel 3  log mel 4  log mel 5  \
# 0   -39.360584 -32.566320 -30.949078 -34.151655 -34.073565 -37.706562
# 1   -37.210178 -28.610222 -26.938998 -26.867491 -26.163156 -28.282885
# 2   -35.306351 -27.769136 -26.486936 -26.796647 -25.320263 -24.785713
# 3   -27.310675 -19.328403 -18.135308 -25.595152 -28.460085 -28.580111
# 4   -27.388344 -19.005872 -17.904271 -25.524858 -27.907300 -28.158141
# 5   -29.100379 -20.893464 -18.658027 -25.428043 -28.018292 -27.966556
# 6   -44.450140 -40.825057 -40.441256 -42.407129 -41.274169 -40.929577
# 7   -36.794387 -33.390993 -32.108121 -31.581412 -30.169008 -31.941708
# 8   -29.996218 -26.435047 -23.676368 -22.458802 -21.990682 -25.463194
# 9   -35.612567 -32.384055 -31.391577 -31.313617 -30.911015 -33.044785
# 10  -34.718778 -31.513634 -30.324651 -29.185855 -28.407675 -31.098543
# 11  -40.139583 -35.858445 -34.873510 -31.100824 -28.934716 -30.639245
# ...

# %%
#IMPORT VOC DATA
CO2_csv_path = 'D:\\the-smell-of-fear\\SmellOfFearProject\\Numerical Data\\CO2_data.csv'
CO2_df = pd.read_csv(CO2_csv_path, usecols = ['Time','CO2'], header = 0, nrows = 74208)
#CO2 only goes to row 74209
print(CO2_df.shape)

movie_specs_path = 'D:\\the-smell-of-fear\\SmellOfFearProject\\Numerical Data\\screening_times.csv'
movie_specs_df = pd.read_csv(movie_specs_path, skiprows = [x for x in range(1,21)], usecols=['movie', 'begin','number visitors','filled %', 'capacity'], header=0)

movie_runtime_path = 'D:\\the-smell-of-fear\\SmellOfFearProject\\Numerical Data\\movie_runtimes.csv'
movie_runtime_df = pd.read_csv(movie_runtime_path, usecols = ['movie', 'runtime (mins)', 'effective runtime'], header = 0, nrows = 6)
print(movie_runtime_df)
#effective runtime - is no of 30s intervals
# Out:
# (74208, 2)
#                                    movie  runtime (mins)  effective runtime
# 0                               Hobbit 2             187                291
# 1                                  Buddy              94                170
# 2                          Machete Kills             107                196
# 3                           Walter Mitty             125                218
# 4  Paranormal Activity - The Marked Ones              84                154
# 5                                Tribute             146                273

# %%
buddy_effective_length = int(movie_runtime_df.iloc[1][2])
machete_effective_length = int(movie_runtime_df.iloc[2][2])
hungergames_effective_length = int(movie_runtime_df.iloc[5][2])
walter_effective_length = int(movie_runtime_df.iloc[3][2])
paranormal_effective_length = int(movie_runtime_df.iloc[4][2])

effective_length = {'Buddy': buddy_effective_length, 'Machete Kills': machete_effective_length,
                    'The Hunger Games: Catching Fire': hungergames_effective_length, 'Walter Mitty': walter_effective_length,
                    'Paranormal Activity': paranormal_effective_length}
print(effective_length)
# Out:
# {'Buddy': 170, 'Machete Kills': 196, 'The Hunger Games: Catching Fire': 273, 'Walter Mitty': 218, 'Paranormal Activity': 154}

# %%
movie_list = ['Buddy', 'Machete Kills', 'Walter Mitty', 'Paranormal Activity', 'The Hunger Games: Catching Fire']
movie = []
movie_time = []
filled = []
count = 0
for i in range(len(movie_specs_df['movie'])):
    if movie_specs_df['movie'][i] in movie_list:
        movie.append(movie_specs_df['movie'][i])
        begin_time = movie_specs_df['begin'][i]
        day = begin_time[:2]; month = begin_time[3:5]; year = begin_time[6:10]; time = begin_time[-5:]
        begin_time = month + '/' + day + "/" + year + " " + time
        movie_time.append(begin_time)
        filled.append(movie_specs_df['filled %'][i])

#two Walter Mitty at 01/04/2014 20:15, so remove the one will less than 10% filled        
movie.pop(37)
movie_time.pop(37)
filled.pop(37)
movie = {'movie': movie, 'begin': movie_time, 'filled %': filled}
movie_df = pd.DataFrame(movie)
print(movie_time)
print(movie_df)
# Out:
# ['12/19/2013 20:00', '12/23/2013 19:35', '12/23/2013 22:30', '12/25/2013 12:10', '12/25/2013 14:50', '12/25/2013 17:35', '12/25/2013 20:20', '12/25/2013 23:10', '12/26/2013 13:15', '12/26/2013 19:30', '12/26/2013 22:25', '12/27/2013 13:15', '12/27/2013 19:30', '12/27/2013 22:25', '12/28/2013 13:15', '12/28/2013 19:30', '12/28/2013 22:25', '12/29/2013 13:15', '12/29/2013 19:30', '12/29/2013 22:25', '12/30/2013 13:15', '12/30/2013 19:30', '12/30/2013 22:25', '12/31/2013 13:15', '01/01/2014 16:25', '01/01/2014 19:30', '01/01/2014 22:25', '01/02/2014 13:45', '01/02/2014 17:15', '01/02/2014 20:15', '01/02/2014 23:15', '01/03/2014 13:45', '01/03/2014 17:15', '01/03/2014 20:15', '01/03/2014 23:15', '01/04/2014 13:45', '01/04/2014 17:15', '01/04/2014 20:15', '01/04/2014 23:15', '01/05/2014 13:45', '01/05/2014 17:15', '01/05/2014 20:15', '01/05/2014 23:15', '01/06/2014 13:50', '01/06/2014 17:15', '01/06/2014 20:15', '01/06/2014 23:15', '01/07/2014 13:45', '01/07/2014 17:15', '01/07/2014 20:15
# ...

# %%
begin_index = []
end_index = []
begin_time = []
movie_name = []
time = []
for i in range(len(movie_df['movie'])):
    time.append(movie_df['begin'][i])
    movie_name.append(movie_df['movie'][i])
for j in range(len(CO2_df['Time'])):
    voc_time = CO2_df['Time'][j][1:17]
    if (voc_time in time) & ((j-1) not in begin_index):
        begin_index.append(j)
        begin_time.append(CO2_df['Time'][j][1:17])
        the_movie_name = movie_df.loc[len(begin_index)-1]['movie']
        the_effective_length = effective_length[the_movie_name]
        end_index.append(j + the_effective_length)
movie_index = pd.DataFrame({'time': begin_time,
                    'movie name': movie_name,
                    'begin index in CO2_df': begin_index,
                    'end index in CO2_df': end_index})
print(movie_index)
# Out:
#                 time                       movie name  begin index in CO2_df  \
# 0   12/19/2013 20:00                     Walter Mitty                   3846
# 1   12/23/2013 19:35                    Machete Kills                  15251
# 2   12/23/2013 22:30                    Machete Kills                  15600
# 3   12/25/2013 12:10                            Buddy                  20100
# 4   12/25/2013 14:50                            Buddy                  20418
# 5   12/25/2013 17:35                            Buddy                  20747
# 6   12/25/2013 20:20                            Buddy                  21076
# 7   12/25/2013 23:10                            Buddy                  21414
# 8   12/26/2013 13:15  The Hunger Games: Catching Fire                  23097
# 9   12/26/2013 19:30                            Buddy                  23843
# 10  12/26/2013 22:25                            Buddy                  24192
# ...

# %%
screening_no = 0
CO2_df['movie name'] = pd.Series(['Others'] * len(CO2_df['Time']))

for index in begin_index:
    movie_name = movie_index['movie name'][screening_no]
                                  
    if movie_name == 'Buddy':
        end_index = index + buddy_effective_length
        CO2_df['movie name'][index: end_index] = pd.Series(['Buddy'] * buddy_effective_length)
                                  
    elif movie_name == 'Machete Kills':
        end_index = index + machete_effective_length
        CO2_df['movie name'][index: end_index] = pd.Series(['Machete Kills'] * machete_effective_length)
                                  
    elif movie_name == 'The Hunger Games: Catching Fire':
        end_index = index + hungergames_effective_length
        CO2_df['movie name'][index: end_index] = pd.Series(['The Hunger Games: Catching Fire'] * hungergames_effective_length)
                                  
    elif movie_name == 'Walter Mitty':
        end_index = index + walter_effective_length
        CO2_df['movie name'][index: end_index] = pd.Series(['Walter Mitty'] * walter_effective_length)
                                  
    elif movie_name == 'Paranormal Activity':
        end_index = index + paranormal_effective_length
        CO2_df['movie name'][index: end_index] = pd.Series(['Paranormal Activity'] * paranormal_effective_length)
                                  
    screening_no = screening_no + 1
    
CO2_df['movie name'].fillna('Others', inplace=True)
CO2_df['movie name'][0] = 'Others'
print(CO2_df)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# ...

# %%
buddy_input_df['movie name'] = pd.Series(['Buddy'] * len(buddy_input_df['Sentiment']))
machete_input_df['movie name'] = pd.Series(['Machete Kills'] * len(machete_input_df['Sentiment']))
walter_input_df['movie name'] = pd.Series(['Walter Mitty'] * len(walter_input_df['Sentiment']))
paranormalActivity_input_df['movie name'] = pd.Series(['Paranormal Activity'] * len(paranormalActivity_input_df['Sentiment']))
hungergames_input_df['movie name'] = pd.Series(['The Hunger Games: Catching Fire'] * len(hungergames_input_df['Sentiment']))

movie_features_input = {'Buddy': buddy_input_df, 'Machete Kills': machete_input_df, 'Walter Mitty': walter_input_df, 
                        'Paranormal Activity': paranormalActivity_input_df, 'The Hunger Games: Catching Fire': hungergames_input_df}

# %%
frames = []
for i in range(len(movie_index['time'])):
    movie_name = movie_index['movie name'][i]
    begin_index = movie_index['begin index in CO2_df'][i]
    end_index = movie_index['end index in CO2_df'][i]
    the_effective_length = effective_length[movie_name]
    coordinate_features_df = movie_features_input[movie_name]
    coordinate_voc_df = CO2_df.loc[begin_index:end_index, :]
    coordinate_voc_df = coordinate_voc_df.reset_index(drop=True)
    frames.append(pd.DataFrame.merge(coordinate_features_df, coordinate_voc_df, left_index=True, right_index=True, how='inner'))
    
print(frames)
# Out:
# [     log mel 0  log mel 1  log mel 2  log mel 3  log mel 4  log mel 5  \
# 0   -38.901741 -31.988283 -34.082791 -35.370575 -33.421879 -31.645655
# 1   -51.161998 -43.405772 -41.112677 -43.874515 -45.780979 -50.226327
# 2   -28.915157 -21.842478 -21.021453 -20.660080 -20.974581 -25.509896
# 3   -31.362518 -24.167936 -23.367874 -22.942468 -24.589998 -28.221225
# 4   -31.797776 -24.068459 -22.874103 -22.800264 -24.462844 -27.184747
# 5   -49.559087 -41.812445 -39.808185 -40.275629 -42.122289 -44.630287
# 6   -37.011900 -34.546771 -35.229491 -35.094405 -26.180290 -25.426613
# 7   -32.001738 -18.977299 -21.369055 -29.754112 -28.105661 -28.934011
# 8   -48.151202 -39.867232 -37.955395 -38.985473 -39.272358 -41.128048
# 9   -43.534879 -37.315081 -35.397749 -35.436486 -35.755348 -37.532937
# 10  -28.657251 -25.497338 -28.272844 -29.905437 -30.834697 -32.357823
# 11  -40.527598 -36.031436 -37.687112 -38.882807 -39.023290 -39.493555
# ...

# %%
#create an overall dataframe
voc_df = pd.concat(frames)
voc_df = voc_df.dropna()
print(voc_df.columns)
print(voc_df)
print(voc_df.shape)
# Out:
# Index(['log mel 0', 'log mel 1', 'log mel 2', 'log mel 3', 'log mel 4',
#        'log mel 5', 'log mel 6', 'log mel 7', 'log mel 8', 'log mel 9',
#        ...
#        'tonnetz 4', 'tonnetz 5', 'R', 'G', 'B', 'Sentiment', 'movie name_x',
#        'Time', 'CO2', 'movie name_y'],
#       dtype='object', length=203)
#      log mel 0  log mel 1  log mel 2  log mel 3  log mel 4  log mel 5  \
# 0   -28.691669 -28.546783 -33.018549 -35.702136 -37.864428 -39.088537
# 1   -46.117163 -41.755444 -37.560012 -39.314363 -42.312125 -41.914429
# 2   -31.949162 -25.590878 -23.021139 -23.845841 -26.669884 -30.330479
# 3   -35.938176 -30.912878 -27.842159 -28.212136 -29.505140 -32.834983
# 4   -26.641858 -24.805113 -26.237503 -28.577358 -29.929263 -32.706287
# 5   -36.994285 -30.779618 -26.984299 -29.229341 -31.964365 -35.534565
# 6   -18.549710 -16.124392 -14.638184 -20.498506 -24.811938 -27.658262
# 7   -26.305608 -22.583656 -19.796207 -22.628778 -29.448985 -36.075605
# ...

# %%
features = voc_df.iloc[:, :-4].values
print(features)
labels = voc_df.iloc[:, -2].values
print(labels)
# Out:
# [[-2.86916686e+01 -2.85467828e+01 -3.30185491e+01 ...  5.00000000e+00
#    7.00000000e+00  4.69016909e-01]
#  [-4.61171626e+01 -4.17554444e+01 -3.75600118e+01 ...  6.00000000e+01
#    7.40000000e+01  4.69016909e-01]
#  [-3.19491620e+01 -2.55908785e+01 -2.30211390e+01 ...  7.30000000e+01
#    8.60000000e+01  6.02539452e-01]
#  ...
#  [-1.36648045e+01 -8.06926504e+00 -8.91122039e+00 ...  1.12000000e+02
#    9.90000000e+01  5.87089496e-02]
#  [-3.20803684e+01 -2.65378675e+01 -2.75104313e+01 ...  9.60000000e+01
#    8.40000000e+01  7.53425753e-01]
#  [-2.87356246e+01 -2.62991740e+01 -2.82396928e+01 ...  1.02000000e+02
#    8.90000000e+01  3.25096348e-01]]
# [ 629.938  634.216  638.425 ... 1090.39  1096.38  1101.06 ]

# %%
#create training and test datasets
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size= 0.20) #80 20 train test split

# %%
sc = StandardScaler()
features_train = sc.fit_transform(features_train)
features_test = sc.transform(features_test)

# %%
regressor = RandomForestRegressor(n_estimators=10000, random_state=0)
regressor.fit(features_train, labels_train)
labels_pred = regressor.predict(features_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(labels_test, labels_pred))
print('Mean Squared Error:', metrics.mean_squared_error(labels_test, labels_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(labels_test, labels_pred)))
# Out:
# Mean Absolute Error: 301.590556257022
# Mean Squared Error: 138759.64619962405
# Root Mean Squared Error: 372.5045586293194
